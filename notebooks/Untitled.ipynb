# %%
import pandas as pd

# %%
df = pd.read_csv('../anger_bipoc_female/responses.csv')

# %%
dfj = pd.read_json('../anger_bipoc_female/responses.json')

# %% [markdown]
# - 0: random
# - 1: null
# - 2: UCB
# - 3: null
# - 4: UCB
# - 5: null
# - 6: UCB
# - 7: null
# - 8: null
# - 9: UCB

# %%
dfj['participant_responses'][9]
# Out:
# [{'alg_label': 'BR_LilUCB',
#   'exp_uid': 'be72eb43102f42ab2582d815887fe0',
#   'network_delay': 0.191203999999999,
#   'timestamp_query_generated': '2021-12-13 23:59:50.553039',
#   'context_type': 'image',
#   'participant_uid': 'be72eb43102f42ab2582d815887fe0_jAKW4Vo3A2oVnufspo9BuL2v5YDCN9',
#   'winner_id': 18,
#   'query_uid': 'a7b8e3f4e13e908c687a6fc822329414',
#   'target_indices': [{'flag': 0,
#     'target': {'exp_uid': 'be72eb43102f42ab2582d815887fe0',
#      'primary_type': 'text',
#      'target_id': 35,
#      'alt_type': 'text',
#      '_id': '61b7ad9c015f6a00c141bc01',
#      'alt_description': 'content\r',
#      'primary_description': 'content\r'},
#     'label': 'left'},
#    {'flag': 1,
#     'target': {'exp_uid': 'be72eb43102f42ab2582d815887fe0',
#      'primary_type': 'text',
#      'target_id': 18,
#      'alt_type': 'text',
#      '_id': '61b7ad9c015f6a00c141bbf0',
#      'alt_description': 'goofy\r',
#      'primary_description': 'goofy\r'},
# ...
